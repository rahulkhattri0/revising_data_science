# %%
import pandas as pd

# %%
import numpy as np

# %%
labels= [ 'a','b','c']

# %%
my_data=[10,20,30]
arr= np.array(my_data)
d={'a':10,'b':20,'c':30}

# %%
pd.Series(data=my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_data,index= labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_data,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data=labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
d={'a':55,'b':67}

# %%
pd.Series(d)
# Out:
# a    55
# b    67
# dtype: int64

# %%
pd.Series(data=[sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1= pd.Series([1,2,3,4],['Usa','abc','ght','tyty'])

# %%
ser1
# Out:
# Usa     1
# abc     2
# ght     3
# tyty    4
# dtype: int64

# %%
ser1['Usa']
# Out:
# 1

# %%
ser3 = pd.Series(data=labels )

# %%
ser3
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
ser3[0]
# Out:
# 'a'

# %%
ser1+ser3
# Out:
# Usa     NaN
# abc     NaN
# ght     NaN
# tyty    NaN
# 0       NaN
# 1       NaN
# 2       NaN
# dtype: object
