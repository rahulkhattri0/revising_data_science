# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df =pd.DataFrame(randn(5,4),['a','b','c','d','e'],['w','x','y','z'])

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df['w']
# Out:
# a    2.706850
# b    0.651118
# c   -2.018168
# d    0.188695
# e    0.190794
# Name: w, dtype: float64

# %%
type(df['w'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.w
# Out:
# a    2.706850
# b    0.651118
# c   -2.018168
# d    0.188695
# e    0.190794
# Name: w, dtype: float64

# %%
df[['w','z']]
# Out:
#           w         z
# a  2.706850  0.503826
# b  0.651118  0.605965
# c -2.018168 -0.589001
# d  0.188695  0.955057
# e  0.190794  0.683509

# %%
df['new'] = df['w'] + df['y'] #new column added

# %%
df
# Out:
#           w         x         y         z       new
# a  2.706850  0.628133  0.907969  0.503826  3.614819
# b  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# c -2.018168  0.740122  0.528813 -0.589001 -1.489355
# d  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# e  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new',axis=1) #delete a column
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('a',axis=0) #row deleted
# Out:
#           w         x         y         z       new
# b  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# c -2.018168  0.740122  0.528813 -0.589001 -1.489355
# d  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# e  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df
# Out:
#           w         x         y         z       new
# a  2.706850  0.628133  0.907969  0.503826  3.614819
# b  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# c -2.018168  0.740122  0.528813 -0.589001 -1.489355
# d  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# e  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# ## in df.drop method:
# 1. for column axis=1
# 2. for row axis=0

# %%
df.shape
# Out:
# (5, 4)

# %%
df[['z','x']]
# Out:
#           z         x
# a  0.503826  0.628133
# b  0.605965 -0.319318
# c -0.589001  0.740122
# d  0.955057 -0.758872
# e  0.683509  1.978757

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df.loc['a']
# Out:
# w    2.706850
# x    0.628133
# y    0.907969
# z    0.503826
# Name: a, dtype: float64

# %%
type(df.loc['a'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Rows and columns are series

# %%
df.iloc[2] #index location
# Out:
# w   -2.018168
# x    0.740122
# y    0.528813
# z   -0.589001
# Name: c, dtype: float64

# %% [markdown]
# ### df.loc can be used to crete subsets or find a particular value in a dataframe

# %%
df.loc['b','y']
# Out:
# -0.8480769834036315

# %%
df.loc[['a','b'],['w','y']]
# Out:
#           w         y
# a  2.706850  0.907969
# b  0.651118 -0.848077

# %% [markdown]
# ### conditional selection

# %%
df>0 #condtional selection
# Out:
#        w      x      y      z
# a   True   True   True   True
# b   True  False  False   True
# c  False   True   True  False
# d   True  False  False   True
# e   True   True   True   True

# %%
booldf =df>0

# %%
booldf
# Out:
#        w      x      y      z
# a   True   True   True   True
# b   True  False  False   True
# c  False   True   True  False
# d   True  False  False   True
# e   True   True   True   True

# %%
df[booldf]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118       NaN       NaN  0.605965
# c       NaN  0.740122  0.528813       NaN
# d  0.188695       NaN       NaN  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[df>0]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118       NaN       NaN  0.605965
# c       NaN  0.740122  0.528813       NaN
# d  0.188695       NaN       NaN  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[df>1]
# Out:
#          w         x         y   z
# a  2.70685       NaN       NaN NaN
# b      NaN       NaN       NaN NaN
# c      NaN       NaN       NaN NaN
# d      NaN       NaN       NaN NaN
# e      NaN  1.978757  2.605967 NaN

# %%
df['w']>0
# Out:
# a     True
# b     True
# c    False
# d     True
# e     True
# Name: w, dtype: bool

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[df['w']>0]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[df['z']<0]
# Out:
#           w         x         y         z
# c -2.018168  0.740122  0.528813 -0.589001

# %%
type(df[df['z']<0])
# Out:
# pandas.core.frame.DataFrame

# %%
resultdf= df[df['z']>0]

# %%
resultdf
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
resultdf['w']
# Out:
# a    2.706850
# b    0.651118
# d    0.188695
# e    0.190794
# Name: w, dtype: float64

# %%
type(resultdf['w'])
# Out:
# pandas.core.series.Series

# %%
df[df['w']>0]['x'] #all in one step
# Out:
# a    0.628133
# b   -0.319318
# d   -0.758872
# e    1.978757
# Name: x, dtype: float64

# %%
df[df['w']>0]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[df['w']>0][['x','y']]
# Out:
#           x         y
# a  0.628133  0.907969
# b -0.319318 -0.848077
# d -0.758872 -0.933237
# e  1.978757  2.605967

# %%
df[(df['w']>0) | (df['y']>1)] # cant use normal python 'or'
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index()# not inplace by default
# Out:
#   index         w         x         y         z
# 0     a  2.706850  0.628133  0.907969  0.503826
# 1     b  0.651118 -0.319318 -0.848077  0.605965
# 2     c -2.018168  0.740122  0.528813 -0.589001
# 3     d  0.188695 -0.758872 -0.933237  0.955057
# 4     e  0.190794  1.978757  2.605967  0.683509

# %%
newind= 'AB BC IP IO OP'.split()

# %%
newind
# Out:
# ['AB', 'BC', 'IP', 'IO', 'OP']

# %%
df['states']= newind

# %%
df
# Out:
#           w         x         y         z states
# a  2.706850  0.628133  0.907969  0.503826     AB
# b  0.651118 -0.319318 -0.848077  0.605965     BC
# c -2.018168  0.740122  0.528813 -0.589001     IP
# d  0.188695 -0.758872 -0.933237  0.955057     IO
# e  0.190794  1.978757  2.605967  0.683509     OP

# %%
df.set_index('states',inplace= True)

# %%
df
# Out:
#                w         x         y         z
# states
# AB      2.706850  0.628133  0.907969  0.503826
# BC      0.651118 -0.319318 -0.848077  0.605965
# IP     -2.018168  0.740122  0.528813 -0.589001
# IO      0.188695 -0.758872 -0.933237  0.955057
# OP      0.190794  1.978757  2.605967  0.683509
