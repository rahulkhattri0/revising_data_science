# %%
import numpy as np
import pandas as pd

# %%
df= { 'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]}

# %%
df= pd.DataFrame(df)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna() #drops null values from your dataframe for column use axis =1
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.dropna(thresh=1)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value='Fill value') #fills value
# Out:
#             A           B  C
# 0         1.0         5.0  1
# 1         2.0  Fill value  2
# 2  Fill value  Fill value  3

# %%
df['A'].fillna(value=df['A'].mean()) #fills mean value
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64
